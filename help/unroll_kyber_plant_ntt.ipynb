# %%
def expand_macro(len_value, poly_value, word_len_value):
    # Define the template for the macro
    macro_template = """
    lh s0,  {len}*{word_len}*0({poly});    lh s1,  {len}*{word_len}*1({poly})
    lh s2,  {len}*{word_len}*2({poly});    lh s3,  {len}*{word_len}*3({poly})
    lh s4,  {len}*{word_len}*4({poly});    lh s5,  {len}*{word_len}*5({poly})
    lh s6,  {len}*{word_len}*6({poly});    lh s7,  {len}*{word_len}*7({poly})
    lh s8,  {len}*{word_len}*8({poly});    lh s9,  {len}*{word_len}*9({poly})
    lh s10, {len}*{word_len}*10({poly});   lh s11, {len}*{word_len}*11({poly})
    lh a2,  {len}*{word_len}*12({poly});   lh a3,  {len}*{word_len}*13({poly})
    lh a4,  {len}*{word_len}*14({poly});   lh a5,  {len}*{word_len}*15({poly})
    """
    # Replace the placeholders with the actual values
    expanded_code = macro_template.format(len=len_value, poly=poly_value, word_len=word_len_value)
    return expanded_code
# Example usage
expanded_code = expand_macro(1, "a0", 2)
print(expanded_code)
# Out:
#     lh s0,  1*2*0(a0);    lh s1,  1*2*1(a0)
#     lh s2,  1*2*2(a0);    lh s3,  1*2*3(a0)
#     lh s4,  1*2*4(a0);    lh s5,  1*2*5(a0)
#     lh s6,  1*2*6(a0);    lh s7,  1*2*7(a0)
#     lh s8,  1*2*8(a0);    lh s9,  1*2*9(a0)
#     lh s10, 1*2*10(a0);   lh s11, 1*2*11(a0)
#     lh a2,  1*2*12(a0);   lh a3,  1*2*13(a0)
#     lh a4,  1*2*14(a0);   lh a5,  1*2*15(a0)

# %%
def expand_store_macro(len_value, poly_value, word_len_value):
    # Define the template for the macro
    macro_template = """
    sh s0,  {len}*{word_len}*0({poly});    sh s1,  {len}*{word_len}*1({poly})
    sh s2,  {len}*{word_len}*2({poly});    sh s3,  {len}*{word_len}*3({poly})
    sh s4,  {len}*{word_len}*4({poly});    sh s5,  {len}*{word_len}*5({poly})
    sh s6,  {len}*{word_len}*6({poly});    sh s7,  {len}*{word_len}*7({poly})
    sh s8,  {len}*{word_len}*8({poly});    sh s9,  {len}*{word_len}*9({poly})
    sh s10, {len}*{word_len}*10({poly});   sh s11, {len}*{word_len}*11({poly})
    sh a2,  {len}*{word_len}*12({poly});   sh a3,  {len}*{word_len}*13({poly})
    sh a4,  {len}*{word_len}*14({poly});   sh a5,  {len}*{word_len}*15({poly})
    """
    # Replace the placeholders with the actual values
    expanded_code = macro_template.format(len=len_value, poly=poly_value, word_len=word_len_value)
    return expanded_code
# Example usage
expanded_code = expand_store_macro(1, "a0", 2)
print(expanded_code)
# Out:
#     sh s0,  1*2*0(a0);    sh s1,  1*2*1(a0)
#     sh s2,  1*2*2(a0);    sh s3,  1*2*3(a0)
#     sh s4,  1*2*4(a0);    sh s5,  1*2*5(a0)
#     sh s6,  1*2*6(a0);    sh s7,  1*2*7(a0)
#     sh s8,  1*2*8(a0);    sh s9,  1*2*9(a0)
#     sh s10, 1*2*10(a0);   sh s11, 1*2*11(a0)
#     sh a2,  1*2*12(a0);   sh a3,  1*2*13(a0)
#     sh a4,  1*2*14(a0);   sh a5,  1*2*15(a0)

# %%
def expand_ct_bfu_x8_macro(
    a_0_0, a_0_1, a_1_0, a_1_1,
    a_2_0, a_2_1, a_3_0, a_3_1,
    a_4_0, a_4_1, a_5_0, a_5_1,
    a_6_0, a_6_1, a_7_0, a_7_1,
    zeta_0, zeta_1, zeta_2, zeta_3,
    zeta_4, zeta_5, zeta_6, zeta_7,
    q16, t_0, t_1, t_2, t_3):
    # Define the template for the macro
    macro_template = """
    mul  {t_0}, {a_0_1}, {zeta_0};   mul  {t_1}, {a_1_1}, {zeta_1}
    mul  {t_2}, {a_2_1}, {zeta_2};   mul  {t_3}, {a_3_1}, {zeta_3}
    srai {t_0}, {t_0}, 16;          srai {t_1}, {t_1}, 16
    addi {t_0}, {t_0}, 8;           addi {t_1}, {t_1}, 8
    mulh {t_0}, {t_0}, {q16};        mulh {t_1}, {t_1}, {q16}
    srai {t_2}, {t_2}, 16;          srai {t_3}, {t_3}, 16
    addi {t_2}, {t_2}, 8;           addi {t_3}, {t_3}, 8
    mulh {t_2}, {t_2}, {q16};        mulh {t_3}, {t_3}, {q16}
    sub  {a_0_1}, {a_0_0}, {t_0};    sub  {a_1_1}, {a_1_0}, {t_1}
    add  {a_0_0}, {a_0_0}, {t_0};    add  {a_1_0}, {a_1_0}, {t_1}
    mul  {t_0}, {a_4_1}, {zeta_4};   mul  {t_1}, {a_5_1}, {zeta_5}
    sub  {a_2_1}, {a_2_0}, {t_2};    sub  {a_3_1}, {a_3_0}, {t_3}
    add  {a_2_0}, {a_2_0}, {t_2};    add  {a_3_0}, {a_3_0}, {t_3}
    mul  {t_2}, {a_6_1}, {zeta_6};   mul  {t_3}, {a_7_1}, {zeta_7}
    srai {t_0}, {t_0}, 16;          srai {t_1}, {t_1}, 16
    addi {t_0}, {t_0}, 8;           addi {t_1}, {t_1}, 8
    mulh {t_0}, {t_0}, {q16};        mulh {t_1}, {t_1}, {q16}
    srai {t_2}, {t_2}, 16;          srai {t_3}, {t_3}, 16
    addi {t_2}, {t_2}, 8;           addi {t_3}, {t_3}, 8
    mulh {t_2}, {t_2}, {q16};        mulh {t_3}, {t_3}, {q16}
    sub  {a_4_1}, {a_4_0}, {t_0};    sub  {a_5_1}, {a_5_0}, {t_1}
    add  {a_4_0}, {a_4_0}, {t_0};    add  {a_5_0}, {a_5_0}, {t_1}
    sub  {a_6_1}, {a_6_0}, {t_2};    sub  {a_7_1}, {a_7_0}, {t_3}
    add  {a_6_0}, {a_6_0}, {t_2};    add  {a_7_0}, {a_7_0}, {t_3}
    """
    # Replace the placeholders with the actual values
    expanded_code = macro_template.format(
        a_0_0=a_0_0, a_0_1=a_0_1, a_1_0=a_1_0, a_1_1=a_1_1,
        a_2_0=a_2_0, a_2_1=a_2_1, a_3_0=a_3_0, a_3_1=a_3_1,
        a_4_0=a_4_0, a_4_1=a_4_1, a_5_0=a_5_0, a_5_1=a_5_1,
        a_6_0=a_6_0, a_6_1=a_6_1, a_7_0=a_7_0, a_7_1=a_7_1,
        zeta_0=zeta_0, zeta_1=zeta_1, zeta_2=zeta_2, zeta_3=zeta_3,
        zeta_4=zeta_4, zeta_5=zeta_5, zeta_6=zeta_6, zeta_7=zeta_7,
        q16=q16, t_0=t_0, t_1=t_1, t_2=t_2, t_3=t_3
    )
    return expanded_code
# Example usage
# expanded_code = expand_ct_bfu_x8_macro(
#       "s0", "s8", "s1", "s9",
#       "s2", "s10", "s3", "s11",
#       "s4", "a2", "s5", "a3",
#       "s6", "a4", "s7", "a5",
#       "t0", "t0", "t0", "t0", 
#       "t0", "t0", "t0", "t0",
#       "a6", "a7", "gp", "tp", "ra"
# )
expanded_code = expand_ct_bfu_x8_macro(
      "s0", "s4", "s1", "s5",   
      "s2", "s6", "s3", "s7",    
      "s8", "a2", "s9", "a3",  
      "s10","a4", "s11","a5", 
      "t1", "t1", "t1", "t1",   
      "t2", "t2", "t2", "t2",   
      "a6", "a7", "gp", "tp", "ra"
)
print(expanded_code)
# Out:
#     mul  a7, s4, t1;   mul  gp, s5, t1
#     mul  tp, s6, t1;   mul  ra, s7, t1
#     srai a7, a7, 16;          srai gp, gp, 16
#     addi a7, a7, 8;           addi gp, gp, 8
#     mulh a7, a7, a6;        mulh gp, gp, a6
#     srai tp, tp, 16;          srai ra, ra, 16
#     addi tp, tp, 8;           addi ra, ra, 8
#     mulh tp, tp, a6;        mulh ra, ra, a6
#     sub  s4, s0, a7;    sub  s5, s1, gp
#     add  s0, s0, a7;    add  s1, s1, gp
#     mul  a7, a2, t2;   mul  gp, a3, t2
#     sub  s6, s2, tp;    sub  s7, s3, ra
#     add  s2, s2, tp;    add  s3, s3, ra
#     mul  tp, a4, t2;   mul  ra, a5, t2
#     srai a7, a7, 16;          srai gp, gp, 16
#     addi a7, a7, 8;           addi gp, gp, 8
#     mulh a7, a7, a6;        mulh gp, gp, a6
#     srai tp, tp, 16;          srai ra, ra, 16
#     addi tp, tp, 8;           addi ra, ra, 8
#     mulh tp, tp, a6;        mulh ra, ra, a6
#     sub  a2, s8, a7;    sub  a3, s9, gp
#     add  s8, s8, a7;    add  s9, s9, gp
# ...

# %%
def expand_ct_bfu_x8_3l_load3zetas_macro(
    a_0_0, a_0_1, a_1_0, a_1_1,
    a_2_0, a_2_1, a_3_0, a_3_1,
    a_4_0, a_4_1, a_5_0, a_5_1,
    a_6_0, a_6_1, a_7_0, a_7_1,
    zeta_0, zeta_2, zeta_4, zeta_6,
    q16, t_0, t_1, t_2, t_3
):
    # Define the template for the macro
    macro_template = """
    lw   {t_3}, {zeta_2}(a1)
    mul  {t_0}, {a_0_1}, {zeta_0};   mul  {t_1}, {a_1_1}, {zeta_0}
    mul  {t_2}, {a_2_1}, {t_3};      mul  {t_3}, {a_3_1}, {t_3}
    srai {t_0}, {t_0}, 16;          srai {t_1}, {t_1}, 16
    srai {t_2}, {t_2}, 16;          srai {t_3}, {t_3}, 16
    addi {t_0}, {t_0}, 8;           addi {t_1}, {t_1}, 8
    addi {t_2}, {t_2}, 8;           addi {t_3}, {t_3}, 8
    mulh {t_0}, {t_0}, {q16};        mulh {t_1}, {t_1}, {q16}
    mulh {t_2}, {t_2}, {q16};        mulh {t_3}, {t_3}, {q16}
    sub  {a_0_1}, {a_0_0}, {t_0};    sub  {a_1_1}, {a_1_0}, {t_1}
    sub  {a_2_1}, {a_2_0}, {t_2};    sub  {a_3_1}, {a_3_0}, {t_3}
    add  {a_0_0}, {a_0_0}, {t_0};    add  {a_1_0}, {a_1_0}, {t_1}
    lw   {t_1}, {zeta_4}(a1)
    add  {a_3_0}, {a_3_0}, {t_3};    add  {a_2_0}, {a_2_0}, {t_2}
    lw   {t_3}, {zeta_6}(a1)
    mul  {t_0}, {a_4_1}, {t_1};      mul  {t_1}, {a_5_1}, {t_1}
    mul  {t_2}, {a_6_1}, {t_3};      mul  {t_3}, {a_7_1}, {t_3}
    srai {t_0}, {t_0}, 16;          srai {t_1}, {t_1}, 16
    srai {t_2}, {t_2}, 16;          srai {t_3}, {t_3}, 16
    addi {t_0}, {t_0}, 8;           addi {t_1}, {t_1}, 8
    addi {t_2}, {t_2}, 8;           addi {t_3}, {t_3}, 8
    mulh {t_0}, {t_0}, {q16};        mulh {t_1}, {t_1}, {q16}
    mulh {t_2}, {t_2}, {q16};        mulh {t_3}, {t_3}, {q16}
    sub  {a_4_1}, {a_4_0}, {t_0};    sub  {a_5_1}, {a_5_0}, {t_1}
    sub  {a_6_1}, {a_6_0}, {t_2};    sub  {a_7_1}, {a_7_0}, {t_3}
    add  {a_4_0}, {a_4_0}, {t_0};    add  {a_5_0}, {a_5_0}, {t_1}
    add  {a_6_0}, {a_6_0}, {t_2};    add  {a_7_0}, {a_7_0}, {t_3}
    """
    # Replace the placeholders with the actual values
    expanded_code = macro_template.format(
        a_0_0=a_0_0, a_0_1=a_0_1, a_1_0=a_1_0, a_1_1=a_1_1,
        a_2_0=a_2_0, a_2_1=a_2_1, a_3_0=a_3_0, a_3_1=a_3_1,
        a_4_0=a_4_0, a_4_1=a_4_1, a_5_0=a_5_0, a_5_1=a_5_1,
        a_6_0=a_6_0, a_6_1=a_6_1, a_7_0=a_7_0, a_7_1=a_7_1,
        zeta_0=zeta_0, zeta_2=zeta_2, zeta_4=zeta_4, zeta_6=zeta_6,
        q16=q16, t_0=t_0, t_1=t_1, t_2=t_2, t_3=t_3
    )
    return expanded_code
# Example usage
expanded_code = expand_ct_bfu_x8_3l_load3zetas_macro(
      "s0", "s2", "s1", "s3",   
      "s4", "s6", "s5", "s7",   
      "s8", "s10","s9", "s11", 
      "a2", "a4", "a3", "a5",   
      "t3", "4*4","5*4","6*4",
      "a6", "a7", "gp", "tp", "ra"
)
print(expanded_code)
# Out:
#     lw   ra, 4*4(a1)
#     mul  a7, s2, t3;   mul  gp, s3, t3
#     mul  tp, s6, ra;      mul  ra, s7, ra
#     srai a7, a7, 16;          srai gp, gp, 16
#     srai tp, tp, 16;          srai ra, ra, 16
#     addi a7, a7, 8;           addi gp, gp, 8
#     addi tp, tp, 8;           addi ra, ra, 8
#     mulh a7, a7, a6;        mulh gp, gp, a6
#     mulh tp, tp, a6;        mulh ra, ra, a6
#     sub  s2, s0, a7;    sub  s3, s1, gp
#     sub  s6, s4, tp;    sub  s7, s5, ra
#     add  s0, s0, a7;    add  s1, s1, gp
#     lw   gp, 5*4(a1)
#     add  s5, s5, ra;    add  s4, s4, tp
#     lw   ra, 6*4(a1)
#     mul  a7, s10, gp;      mul  gp, s11, gp
#     mul  tp, a4, ra;      mul  ra, a5, ra
#     srai a7, a7, 16;          srai gp, gp, 16
#     srai tp, tp, 16;          srai ra, ra, 16
#     addi a7, a7, 8;           addi gp, gp, 8
#     addi tp, tp, 8;           addi ra, ra, 8
#     mulh a7, a7, a6;        mulh gp, gp, a6
#     mulh tp, tp, a6;        mulh ra, ra, a6
# ...

# %%
def expand_ct_bfu_x8_4l_load8zetas_macro(
    a_0_0, a_0_1, a_1_0, a_1_1,
    a_2_0, a_2_1, a_3_0, a_3_1,
    a_4_0, a_4_1, a_5_0, a_5_1,
    a_6_0, a_6_1, a_7_0, a_7_1,
    zeta_0, zeta_1,
    zeta_2, zeta_3,
    zeta_4, zeta_5,
    zeta_6, zeta_7,
    q16,
    t_0, t_1, t_2, t_3
):
    # Define the template for the macro
    macro_template = """
    lw   {t_0}, {zeta_0}(a1);     lw   {t_1}, {zeta_1}(a1)
    lw   {t_2}, {zeta_2}(a1);     lw   {t_3}, {zeta_3}(a1)
    mul  {t_0}, {a_0_1}, {t_0};    mul  {t_1}, {a_1_1}, {t_1}
    mul  {t_2}, {a_2_1}, {t_2};    mul  {t_3}, {a_3_1}, {t_3}
    srai {t_0}, {t_0}, 16;        srai {t_1}, {t_1}, 16
    addi {t_0}, {t_0}, 8;         addi {t_1}, {t_1}, 8
    mulh {t_0}, {t_0}, {q16};      mulh {t_1}, {t_1}, {q16}
    srai {t_2}, {t_2}, 16;        srai {t_3}, {t_3}, 16
    addi {t_2}, {t_2}, 8;         addi {t_3}, {t_3}, 8
    mulh {t_2}, {t_2}, {q16};      mulh {t_3}, {t_3}, {q16}
    sub  {a_0_1}, {a_0_0}, {t_0};  sub  {a_1_1}, {a_1_0}, {t_1}
    add  {a_0_0}, {a_0_0}, {t_0};  lw   {t_0}, {zeta_4}(a1)
    add  {a_1_0}, {a_1_0}, {t_1};  lw   {t_1}, {zeta_5}(a1)
    mul  {t_0}, {a_4_1}, {t_0};    mul  {t_1}, {a_5_1}, {t_1}
    sub  {a_2_1}, {a_2_0}, {t_2};  sub  {a_3_1}, {a_3_0}, {t_3}
    add  {a_2_0}, {a_2_0}, {t_2};  lw   {t_2}, {zeta_6}(a1)
    add  {a_3_0}, {a_3_0}, {t_3};  lw   {t_3}, {zeta_7}(a1)
    mul  {t_2}, {a_6_1}, {t_2};    mul  {t_3}, {a_7_1}, {t_3}
    srai {t_0}, {t_0}, 16;        srai {t_1}, {t_1}, 16
    addi {t_0}, {t_0}, 8;         addi {t_1}, {t_1}, 8
    mulh {t_0}, {t_0}, {q16};      mulh {t_1}, {t_1}, {q16}
    srai {t_2}, {t_2}, 16;        srai {t_3}, {t_3}, 16
    addi {t_2}, {t_2}, 8;         addi {t_3}, {t_3}, 8
    mulh {t_2}, {t_2}, {q16};      mulh {t_3}, {t_3}, {q16}
    sub  {a_4_1}, {a_4_0}, {t_0};  sub  {a_5_1}, {a_5_0}, {t_1}
    add  {a_4_0}, {a_4_0}, {t_0};  add  {a_5_0}, {a_5_0}, {t_1}
    sub  {a_6_1}, {a_6_0}, {t_2};  sub  {a_7_1}, {a_7_0}, {t_3}
    add  {a_6_0}, {a_6_0}, {t_2};  add  {a_7_0}, {a_7_0}, {t_3}
    """
    # Replace the placeholders with the actual values
    expanded_code = macro_template.format(
        a_0_0=a_0_0, a_0_1=a_0_1, a_1_0=a_1_0, a_1_1=a_1_1,
        a_2_0=a_2_0, a_2_1=a_2_1, a_3_0=a_3_0, a_3_1=a_3_1,
        a_4_0=a_4_0, a_4_1=a_4_1, a_5_0=a_5_0, a_5_1=a_5_1,
        a_6_0=a_6_0, a_6_1=a_6_1, a_7_0=a_7_0, a_7_1=a_7_1,
        zeta_0=zeta_0, zeta_1=zeta_1, zeta_2=zeta_2, zeta_3=zeta_3,
        zeta_4=zeta_4, zeta_5=zeta_5, zeta_6=zeta_6, zeta_7=zeta_7,
        q16=q16, t_0=t_0, t_1=t_1, t_2=t_2, t_3=t_3
    )
    return expanded_code
# Example usage
expanded_code = expand_ct_bfu_x8_4l_load8zetas_macro(
    "s0", "s1", "s2", "s3",
    "s4", "s5", "s6", "s7",
    "s8", "s9", "s10", "s11",
    "a2", "a3", "a4", "a5",
    "7*4", "8*4", "9*4", "10*4",
    "11*4", "12*4", "13*4", "14*4",
    "a6", "a7", "gp", "tp", "ra"
)
print(expanded_code)
# Out:
#     lw   a7, 7*4(a1);     lw   gp, 8*4(a1)
#     lw   tp, 9*4(a1);     lw   ra, 10*4(a1)
#     mul  a7, s1, a7;    mul  gp, s3, gp
#     mul  tp, s5, tp;    mul  ra, s7, ra
#     srai a7, a7, 16;        srai gp, gp, 16
#     addi a7, a7, 8;         addi gp, gp, 8
#     mulh a7, a7, a6;      mulh gp, gp, a6
#     srai tp, tp, 16;        srai ra, ra, 16
#     addi tp, tp, 8;         addi ra, ra, 8
#     mulh tp, tp, a6;      mulh ra, ra, a6
#     sub  s1, s0, a7;  sub  s3, s2, gp
#     add  s0, s0, a7;  lw   a7, 11*4(a1)
#     add  s2, s2, gp;  lw   gp, 12*4(a1)
#     mul  a7, s9, a7;    mul  gp, s11, gp
#     sub  s5, s4, tp;  sub  s7, s6, ra
#     add  s4, s4, tp;  lw   tp, 13*4(a1)
#     add  s6, s6, ra;  lw   ra, 14*4(a1)
#     mul  tp, a3, tp;    mul  ra, a5, ra
#     srai a7, a7, 16;        srai gp, gp, 16
#     addi a7, a7, 8;         addi gp, gp, 8
#     mulh a7, a7, a6;      mulh gp, gp, a6
#     srai tp, tp, 16;        srai ra, ra, 16
# ...

# %%
def expand_ct_bfu_x8_macro(
    a_0_0, a_0_1, a_1_0, a_1_1,
    a_2_0, a_2_1, a_3_0, a_3_1,
    a_4_0, a_4_1, a_5_0, a_5_1,
    a_6_0, a_6_1, a_7_0, a_7_1,
    zeta_0, zeta_1, zeta_2, zeta_3,
    zeta_4, zeta_5, zeta_6, zeta_7,
    q16, t_0, t_1, t_2, t_3):
    # Define the template for the macro
    macro_template = """
    mul  {t_0}, {a_0_1}, {zeta_0};   mul  {t_1}, {a_1_1}, {zeta_1}
    mul  {t_2}, {a_2_1}, {zeta_2};   mul  {t_3}, {a_3_1}, {zeta_3}
    srai {t_0}, {t_0}, 16;          srai {t_1}, {t_1}, 16
    addi {t_0}, {t_0}, 8;           addi {t_1}, {t_1}, 8
    mulh {t_0}, {t_0}, {q16};        mulh {t_1}, {t_1}, {q16}
    srai {t_2}, {t_2}, 16;          srai {t_3}, {t_3}, 16
    addi {t_2}, {t_2}, 8;           addi {t_3}, {t_3}, 8
    mulh {t_2}, {t_2}, {q16};        mulh {t_3}, {t_3}, {q16}
    sub  {a_0_1}, {a_0_0}, {t_0};    sub  {a_1_1}, {a_1_0}, {t_1}
    add  {a_0_0}, {a_0_0}, {t_0};    add  {a_1_0}, {a_1_0}, {t_1}
    mul  {t_0}, {a_4_1}, {zeta_4};   mul  {t_1}, {a_5_1}, {zeta_5}
    sub  {a_2_1}, {a_2_0}, {t_2};    sub  {a_3_1}, {a_3_0}, {t_3}
    add  {a_2_0}, {a_2_0}, {t_2};    add  {a_3_0}, {a_3_0}, {t_3}
    mul  {t_2}, {a_6_1}, {zeta_6};   mul  {t_3}, {a_7_1}, {zeta_7}
    srai {t_0}, {t_0}, 16;          srai {t_1}, {t_1}, 16
    addi {t_0}, {t_0}, 8;           addi {t_1}, {t_1}, 8
    mulh {t_0}, {t_0}, {q16};        mulh {t_1}, {t_1}, {q16}
    srai {t_2}, {t_2}, 16;          srai {t_3}, {t_3}, 16
    addi {t_2}, {t_2}, 8;           addi {t_3}, {t_3}, 8
    mulh {t_2}, {t_2}, {q16};        mulh {t_3}, {t_3}, {q16}
    sub  {a_4_1}, {a_4_0}, {t_0};    sub  {a_5_1}, {a_5_0}, {t_1}
    add  {a_4_0}, {a_4_0}, {t_0};    add  {a_5_0}, {a_5_0}, {t_1}
    sub  {a_6_1}, {a_6_0}, {t_2};    sub  {a_7_1}, {a_7_0}, {t_3}
    add  {a_6_0}, {a_6_0}, {t_2};    add  {a_7_0}, {a_7_0}, {t_3}
    """
    # Replace the placeholders with the actual values
    expanded_code = macro_template.format(
        a_0_0=a_0_0, a_0_1=a_0_1, a_1_0=a_1_0, a_1_1=a_1_1,
        a_2_0=a_2_0, a_2_1=a_2_1, a_3_0=a_3_0, a_3_1=a_3_1,
        a_4_0=a_4_0, a_4_1=a_4_1, a_5_0=a_5_0, a_5_1=a_5_1,
        a_6_0=a_6_0, a_6_1=a_6_1, a_7_0=a_7_0, a_7_1=a_7_1,
        zeta_0=zeta_0, zeta_1=zeta_1, zeta_2=zeta_2, zeta_3=zeta_3,
        zeta_4=zeta_4, zeta_5=zeta_5, zeta_6=zeta_6, zeta_7=zeta_7,
        q16=q16, t_0=t_0, t_1=t_1, t_2=t_2, t_3=t_3
    )
    return expanded_code
# Example usage
# expanded_code = expand_ct_bfu_x8_macro(
#       "s0", "s8", "s1", "s9",
#       "s2", "s10", "s3", "s11",
#       "s4", "a2", "s5", "a3",
#       "s6", "a4", "s7", "a5",
#       "t0", "t0", "t0", "t0", 
#       "t0", "t0", "t0", "t0",
#       "a6", "a7", "gp", "tp", "ra"
# )
expanded_code = expand_ct_bfu_x8_macro(
      "s0", "s4", "s1", "s5",   
      "s2", "s6", "s3", "s7",    
      "s8", "a2", "s9", "a3",  
      "s10","a4", "s11","a5", 
      "t1", "t1", "t1", "t1",   
      "t2", "t2", "t2", "t2",   
      "a6", "a7", "gp", "tp", "ra"
)
print(expanded_code)
# Out:
#     mul  a7, s4, t1;   mul  gp, s5, t1
#     mul  tp, s6, t1;   mul  ra, s7, t1
#     srai a7, a7, 16;          srai gp, gp, 16
#     addi a7, a7, 8;           addi gp, gp, 8
#     mulh a7, a7, a6;        mulh gp, gp, a6
#     srai tp, tp, 16;          srai ra, ra, 16
#     addi tp, tp, 8;           addi ra, ra, 8
#     mulh tp, tp, a6;        mulh ra, ra, a6
#     sub  s4, s0, a7;    sub  s5, s1, gp
#     add  s0, s0, a7;    add  s1, s1, gp
#     mul  a7, a2, t2;   mul  gp, a3, t2
#     sub  s6, s2, tp;    sub  s7, s3, ra
#     add  s2, s2, tp;    add  s3, s3, ra
#     mul  tp, a4, t2;   mul  ra, a5, t2
#     srai a7, a7, 16;          srai gp, gp, 16
#     addi a7, a7, 8;           addi gp, gp, 8
#     mulh a7, a7, a6;        mulh gp, gp, a6
#     srai tp, tp, 16;          srai ra, ra, 16
#     addi tp, tp, 8;           addi ra, ra, 8
#     mulh tp, tp, a6;        mulh ra, ra, a6
#     sub  a2, s8, a7;    sub  a3, s9, gp
#     add  s8, s8, a7;    add  s9, s9, gp
# ...

# %%
def expand_shuffle4_macro(out0, out1, in0, in1, vt0, vt1):
    macro_template = """
    vrgather.vv {out1}, {in0}, {vt0}
    vrgather.vv {out0}, {in1}, {vt1}
    vmerge.vvm {out1}, {in1}, {out1}, v0
    vmerge.vvm {out0}, {out0}, {in0}, v0
    """
    return macro_template.format(out0=out0, out1=out1, in0=in0, in1=in1, vt0=vt0, vt1=vt1)

def expand_shuffle2_macro(out0, out1, in0, in1, vmt0, vmt1):
    macro_template = """
    vrgather.vv {out0}, {in1}, {vmt0}
    vmerge.vvm  {out0}, {out0}, {in0}, v0
    vrgather.vv {out1}, {in0}, {vmt1}
    vmerge.vvm  {out1}, {in1}, {out1}, v0
    """
    return macro_template.format(out0=out0, out1=out1, in0=in0, in1=in1, vmt0=vmt0, vmt1=vmt1)

def expand_shuffle1_macro(out0, out1, in0, in1, vmt0):
    macro_template = """
    vrgather.vv {out0}, {in1}, {vmt0}
    vrgather.vv {out1}, {in0}, {vmt0}
    vmerge.vvm  {out0}, {out0}, {in0}, v0
    vmerge.vvm  {out1}, {in1}, {out1}, v0
    """
    return macro_template.format(out0=out0, out1=out1, in0=in0, in1=in1, vmt0=vmt0)

# Example usage
expanded_code_shuffle4 = expand_shuffle4_macro('v1', 'v2', 'v9',  'v17', 'v31', 'v30')
print("Expanded shuffle4 macro:\n", expanded_code_shuffle4)
expanded_code_shuffle4 = expand_shuffle4_macro('v3', 'v4', 'v10', 'v18', 'v31', 'v30')
print("Expanded shuffle4 macro:\n", expanded_code_shuffle4)
expanded_code_shuffle4 = expand_shuffle4_macro('v5', 'v6', 'v11', 'v19', 'v31', 'v30')
print("Expanded shuffle4 macro:\n", expanded_code_shuffle4)
expanded_code_shuffle4 = expand_shuffle4_macro('v7', 'v8', 'v12', 'v20', 'v31', 'v30')
print("Expanded shuffle4 macro:\n", expanded_code_shuffle4)
expanded_code_shuffle4 = expand_shuffle4_macro('v1', 'v2', 'v13', 'v21', 'v31', 'v30')
print("Expanded shuffle4 macro:\n", expanded_code_shuffle4)
expanded_code_shuffle4 = expand_shuffle4_macro('v3', 'v4', 'v14', 'v22', 'v31', 'v30')
print("Expanded shuffle4 macro:\n", expanded_code_shuffle4)
expanded_code_shuffle4 = expand_shuffle4_macro('v5', 'v6', 'v15', 'v23', 'v31', 'v30')
print("Expanded shuffle4 macro:\n", expanded_code_shuffle4)
expanded_code_shuffle4 = expand_shuffle4_macro('v7', 'v8', 'v16', 'v24', 'v31', 'v30')
print("Expanded shuffle4 macro:\n", expanded_code_shuffle4)

expanded_code_shuffle2 = expand_shuffle2_macro('v1', 'v2', 'v9', 'v11', 'v29', 'v28')
print("Expanded shuffle2 macro:\n", expanded_code_shuffle2)
expanded_code_shuffle2 = expand_shuffle2_macro('v3', 'v4', 'v17','v19', 'v29', 'v28')
print("Expanded shuffle2 macro:\n", expanded_code_shuffle2)
expanded_code_shuffle2 = expand_shuffle2_macro('v5', 'v6', 'v10','v12', 'v29', 'v28')
print("Expanded shuffle2 macro:\n", expanded_code_shuffle2)
expanded_code_shuffle2 = expand_shuffle2_macro('v7', 'v8', 'v18','v20', 'v29', 'v28')
print("Expanded shuffle2 macro:\n", expanded_code_shuffle2)
expanded_code_shuffle2 = expand_shuffle2_macro('v1', 'v2', 'v13','v15', 'v29', 'v28')
print("Expanded shuffle2 macro:\n", expanded_code_shuffle2)
expanded_code_shuffle2 = expand_shuffle2_macro('v3', 'v4', 'v21','v23', 'v29', 'v28')
print("Expanded shuffle2 macro:\n", expanded_code_shuffle2)
expanded_code_shuffle2 = expand_shuffle2_macro('v5', 'v6', 'v14','v16', 'v29', 'v28')
print("Expanded shuffle2 macro:\n", expanded_code_shuffle2)
expanded_code_shuffle2 = expand_shuffle2_macro('v7', 'v8', 'v22','v24', 'v29', 'v28')
print("Expanded shuffle2 macro:\n", expanded_code_shuffle2)

expanded_code_shuffle1 = expand_shuffle1_macro('v1', 'v2', 'v9',  'v11', 'v27')
print("Expanded shuffle1 macro:\n", expanded_code_shuffle1)
expanded_code_shuffle1 = expand_shuffle1_macro('v3', 'v4', 'v17', 'v19', 'v27')
print("Expanded shuffle1 macro:\n", expanded_code_shuffle1)
expanded_code_shuffle1 = expand_shuffle1_macro('v5', 'v6', 'v10', 'v12', 'v27')
print("Expanded shuffle1 macro:\n", expanded_code_shuffle1)
expanded_code_shuffle1 = expand_shuffle1_macro('v7', 'v8', 'v18', 'v20', 'v27')
print("Expanded shuffle1 macro:\n", expanded_code_shuffle1)
expanded_code_shuffle1 = expand_shuffle1_macro('v9',  'v11', 'v13', 'v15', 'v27')
print("Expanded shuffle1 macro:\n", expanded_code_shuffle1)
expanded_code_shuffle1 = expand_shuffle1_macro('v17', 'v19', 'v21', 'v23', 'v27')
print("Expanded shuffle1 macro:\n", expanded_code_shuffle1)
expanded_code_shuffle1 = expand_shuffle1_macro('v10', 'v12', 'v14', 'v16', 'v27')
print("Expanded shuffle1 macro:\n", expanded_code_shuffle1)
expanded_code_shuffle1 = expand_shuffle1_macro('v18', 'v20', 'v22', 'v24', 'v27')
print("Expanded shuffle1 macro:\n", expanded_code_shuffle1)
# Out:
# Expanded shuffle4 macro:
#
#     vrgather.vv v2, v9, v31
#     vrgather.vv v1, v17, v30
#     vmerge.vvm v2, v17, v2, v0
#     vmerge.vvm v1, v1, v9, v0
#
# Expanded shuffle4 macro:
#
#     vrgather.vv v4, v10, v31
#     vrgather.vv v3, v18, v30
#     vmerge.vvm v4, v18, v4, v0
#     vmerge.vvm v3, v3, v10, v0
#
# Expanded shuffle4 macro:
#
#     vrgather.vv v6, v11, v31
#     vrgather.vv v5, v19, v30
#     vmerge.vvm v6, v19, v6, v0
#     vmerge.vvm v5, v5, v11, v0
#
# Expanded shuffle4 macro:
#
#     vrgather.vv v8, v12, v31
#     vrgather.vv v7, v20, v30
#     vmerge.vvm v8, v20, v8, v0
#     vmerge.vvm v7, v7, v12, v0
#
# Expanded shuffle4 macro:
#
#     vrgather.vv v2, v13, v31
#     vrgather.vv v1, v21, v30
#     vmerge.vvm v2, v21, v2, v0
#     vmerge.vvm v1, v1, v13, v0
#
# Expanded shuffle4 macro:
#
#     vrgather.vv v4, v14, v31
#     vrgather.vv v3, v22, v30
#     vmerge.vvm v4, v22, v4, v0
#     vmerge.vvm v3, v3, v14, v0
#
# Expanded shuffle4 macro:
#
# ...
