# %%
def generate_code(outh, outl, in00h, in00l, in01h, in01l, in02h, in02l, Temph, Templ):
    code = f"""
    .macro xoror {outh}, {outl}, {in00h}, {in00l}, {in01h}, {in01l}, {in02h}, {in02l}, {Temph}, {Templ}
        or  {Temph}, {in01h}, {in02h}
        or  {Templ}, {in01l}, {in02l}
        xor {outh}, {in00h}, {Temph}
        xor {outl}, {in00l}, {Templ}
    .endm
    """

    return code

# 提供参数列表
params_list = [
    '\S16h', '\S16l', '\S16h', '\S16l', '\S17h', '\S17l', '\T00h', '\T00l', '\T03h', '\T03l',
    '\T03h', '\T03l', '\T00h', '\T00l', '\T01h', '\T01l', '\S02h', '\S02l', '\T03h', '\T03l',
    '\T03h', '\T03l', '\T02h', '\T02l', '\S04h', '\S04l', '\T00h', '\T00l', '\T03h', '\T03l',
]

# 生成最终代码
final_code = ""
for i in range(0, len(params_list), 10):
    params = params_list[i:i + 10]
    final_code += generate_code(*params)

print(final_code)

# %%
def generate_code(outh, outl, in00h, in00l, in01h, in01l, in02h, in02l, Temph, Templ):
    code = f"""
    .macro xorand {outh}, {outl}, {in00h}, {in00l}, {in01h}, {in01l}, {in02h}, {in02l}, {Temph}, {Templ}
    and {Temph}, {in01h}, {in02h}
    and {Templ}, {in01l}, {in02l}
    xor {outh}, {in00h}, {Temph}
    xor {outl}, {in00l}, {Templ}
    .endm
    """

    return code

# 提供参数列表
params_list = [
    'T02h', 'T02l', 'T02h', 'T02l', 'S05h', 'S05l', 'T00h', 'T00l', 'T03h', 'T03l',
    'S14h', 'S14l', 'S14h', 'S14l', 'S10h', 'S10l', 'T02h', 'T02l', 'T03h', 'T03l',
    'T02h', 'T02l', 'T02h', 'T02l', 'T00h', 'T00l', 'T01h', 'T01l', 'T03h', 'T03l',
    'T02h', 'T02l', 'T02h', 'T02l', 'S16h', 'S16l', 'S17h', 'S17l', 'T03h', 'T03l',
    'T03h', 'T03l', 'T00h', 'T00l', 'T01h', 'T01l', 'S21h', 'S21l', 'T03h', 'T03l',
    'T02h', 'T02l', 'T02h', 'T02l', 'S23h', 'S23l', 'T00h', 'T00l', 'T03h', 'T03l',
    'S02h', 'S02l', 'S02h', 'S02l', 'T02h', 'T02l', 'S04h', 'S04l', 'T03h', 'T03l',
    'S04h', 'S04l', 'S04h', 'S04l', 'T00h', 'T00l', 'T01h', 'T01l', 'T03h', 'T03l',
]

# 生成最终代码
final_code = ""
for i in range(0, len(params_list), 10):
    params = params_list[i:i + 10]
    final_code += generate_code(*params)

print(final_code)

# %%
def generate_code(outh, outl, in00h, in00l, in01h, in01l, in02h, in02l, Temph, Templ):
    code = f"""
    .macro xornotand {outh}, {outl}, {in00h}, {in00l}, {in01h}, {in01l}, {in02h}, {in02l}, {Temph}, {Templ}
        not {Temph}, {in01h}
        not {Templ}, {in01l}
        and {Temph}, {Temph}, {in02h}
        and {Templ}, {Templ}, {in02l}
        xor {outh}, {in00h}, {Temph}
        xor {outl}, {in00l}, {Templ}
    .endm
    """

    return code

# 提供参数列表
params_list = [
    'T03h', 'T03l', 'T00h', 'T00l', 'T01h', 'T01l', 'S14h', 'S14l', 'T03h', 'T03l',
    'T03h', 'T03l', 'T01h', 'T01l', 'S21h', 'S21l', 'T02h', 'T02l', 'T03h', 'T03l',
]

# 生成最终代码
final_code = ""
for i in range(0, len(params_list), 10):
    params = params_list[i:i + 10]
    final_code += generate_code(*params)

print(final_code)

# %%
def generate_code(outh, outl, in00h, in00l, in01h, in01l, in02h, in02l, Temph, Templ, T0):
    code = f"""
    .macro notxoror {outh}, {outl}, {in00h}, {in00l}, {in01h}, {in01l}, {in02h}, {in02l}, {Temph}, {Templ}, {T0}
    not {T0}, {in00h}
    or  {Temph}, {in01h}, {in02h}
    xor {outh}, {Temph}, {T0}
    not {T0}, {in00l}
    or  {Templ}, {in01l}, {in02l}
    xor {outl}, {Templ}, {T0}
    .endm
    """

    return code

# 提供参数列表
params_list = [
    '\\T03h', '\\T03l', '\\T01h', '\\T01l', '\\S14h', '\\S14l', '\\S10h', '\\S10l', '\\T03h', '\\T03l', '\\T04',
    '\\S21h', '\\S21l', '\\S21h', '\\S21l', '\\T02h', '\\T02l', '\\S23h', '\\S23l', '\\T03h', '\\T03l', '\\T04',
]

# 生成最终代码
final_code = ""
for i in range(0, len(params_list), 11):
    params = params_list[i:i + 11]
    final_code += generate_code(*params)

print(final_code)

# %%
def generate_code(outh, outl, in00h, in00l, in01h, in01l, in02h, in02l, Temph, Templ, T0):
    code = f"""
    .macro notxorand {outh}, {outl}, {in00h}, {in00l}, {in01h}, {in01l}, {in02h}, {in02l}, {Temph}, {Templ}, {T0}
    not {T0}, {in00h}
    and {Temph}, {in01h}, {in02h}
    xor {outh}, {Temph}, {T0}
    not {T0}, {in00l}
    and {Templ}, {in01l}, {in02l}
    xor {outl}, {Templ}, {T0}
    .endm
    """

    return code

# 提供参数列表
params_list = [
    '\\T03h', '\\T03l', '\\T00h', '\\T00l', '\\T01h', '\\T01l', '\\T02h', '\\T02l', '\\T03h', '\\T03l', '\\T04',
]

# 生成最终代码
final_code = ""
for i in range(0, len(params_list), 11):
    params = params_list[i:i + 11]
    final_code += generate_code(*params)

print(final_code)

# %%
def generate_code(outh, outl, in00h, in00l, in01h, in01l, in02h, in02l, Temph, Templ):
    code = f"""
    .macro xornotor {outh}, {outl}, {in00h}, {in00l}, {in01h}, {in01l}, {in02h}, {in02l}, {Temph}, {Templ}
    not {Temph}, {in01h}
    not {Templ}, {in01l}
    or {Temph}, {Temph}, {in02h}
    or {Templ}, {Templ}, {in02l}
    xor {outh}, {in00h}, {Temph}
    xor {outl}, {in00l}, {Templ}
    .endm
    """

    return code

# 提供参数列表
params_list = [
    '\\T03h', '\\T03l', '\\T01h', '\\T01l', '\\S02h', '\\S02l', '\\T02h', '\\T02l', '\\T03h', '\\T03l',
]

# 生成最终代码
final_code = ""
for i in range(0, len(params_list), 10):
    params = params_list[i:i + 10]
    final_code += generate_code(*params)

print(final_code)

# %%
def generate_code(outh, outl, in0h, in0l, in1h, in1l):
    code = f"""
    .macro XOR1Init {outh}, {outl}, {in0h}, {in0l}, {in1h}, {in1l}
    xor {outh}, {in0h}, {in1h}
    xor {outl}, {in0l}, {in1l}
    .endm
    """

    return code

# 提供参数列表
params_list = [
    ('\\T00h', '\\T00l', '\\S05h', '\\S05l', '\\S10h', '\\S10l'),
    ('\\T01h', '\\T01l', '\\S08h', '\\S08l', '\\S23h', '\\S23l'),
    ('\\T01h', '\\T01l', '\\S04h', '\\S04l', '\\S14h', '\\S14l'),
    ('\\T00h', '\\T00l', '\\S16h', '\\S16l', '\\S21h', '\\S21l'),
    ('\\T00h', '\\T00l', '\\S02h', '\\S02l', '\\S17h', '\\S17l'),
]

# 生成最终代码
final_code = ""
for params in params_list:
    final_code += generate_code(*params)

print(final_code)

# %%
def generate_code(outh, outl, inh, inl):
    code = f"""
    .macro XOR1 {outh}, {outl}, {inh}, {inl}
    xor {outh}, {outh}, {inh}
    xor {outl}, {outl}, {inl}
    .endm
    """

    return code

# 提供参数列表
params_list = [
    '\\T00h, \\T00l, \\T03h, \\T03l',
    '\\T00h, \\T00l, \\T02h, \\T02l',
    '\\T00h, \\T00l, \\T03h, \\T03l',
    '\\T01h, \\T01l, \\T03h, \\T03l',
    '\\T01h, \\T01l, \\T02h, \\T02l',
    '\\T01h, \\T01l, \\T03h, \\T03l',
    '\\S04h, \\S04l, \\T00h, \\T00l',
    '\\S14h, \\S14l, \\T00h, \\T00l',
    '\\T01h, \\T01l, \\T03h, \\T03l',
    '\\T03h, \\T03l, \\T00h, \\T00l',
    '\\T01h, \\T01l, \\T02h, \\T02l',
    '\\T02h, \\T02l, \\T00h, \\T00l',
    '\\T01h, \\T01l, \\T03h, \\T03l',
    '\\T03h, \\T03l, \\T00h, \\T00l',
    '\\T00h, \\T00l, \\T03h, \\T03l',
    '\\T00h, \\T00l, \\T02h, \\T02l',
    '\\T00h, \\T00l, \\T03h, \\T03l',
    '\\S05h, \\S05l, \\T00h, \\T00l',
    '\\T02h, \\T02l, \\T00h, \\T00l',
    '\\S10h, \\S10l, \\T00h, \\T00l',
    '\\T02h, \\T02l, \\T00h, \\T00l',
    '\\T03h, \\T03l, \\T00h, \\T00l',
    '\\T00h, \\T00l, \\T03h, \\T03l',
    '\\T03h, \\T03l, \\T02h, \\T02l',
    '\\S02h, \\S02l, \\T02h, \\T02l',
    '\\T00h, \\T00l, \\T03h, \\T03l',
    '\\T03h, \\T03l, \\T02h, \\T02l',
    '\\S17h, \\S17l, \\T02h, \\T02l',
    '\\T00h, \\T00l, \\T03h, \\T03l',
    '\\T03h, \\T03l, \\T02h, \\T02l',
    '\\S08h, \\S08l, \\T01h, \\T01l',
    '\\T03h, \\T03l, \\T01h, \\T01l',
    '\\S23h, \\S23l, \\T01h, \\T01l',
    '\\T02h, \\T02l, \\T01h, \\T01l',
    '\\T03h, \\T03l, \\T01h, \\T01l',
    '\\S16h, \\S16l, \\T00h, \\T00l',
    '\\T02h, \\T02l, \\T00h, \\T00l',
    '\\S21h, \\S21l, \\T00h, \\T00l',
    '\\T03h, \\T03l, \\T00h, \\T00l',
    '\\T02h, \\T02l, \\T00h, \\T00l',
    '\\T03h, \\T03l, \\T02h, \\T02l',
]

# 生成最终代码
final_code = ""
for params_str in params_list:
    params = params_str.split(', ')
    final_code += generate_code(*params)

print(final_code)

# %%
def generate_code(outh, outl, inh, inl, n):
    code = f"""
    .macro ROLn_e {outh}, {outl}, {inh}, {inl}, {n}
    rori {outh}, {inh}, 32-{n}
    rori {outl}, {inl}, 32-{n}
    .endm
    """

    return code

# 提供参数列表
params_list = [
    '\\T03h, \\T03l, \\S21h, \\S21l, 1',
    '\\T01h, \\T01l, \\T02h, \\T02l, 22',
    '\\S16h, \\S16l, \\S05h, \\S05l, 18',
    '\\S05h, \\S05l, \\T02h, \\T02l, 14',
    '\\T02h, \\T02l, \\S02h, \\S02l, 31',
    '\\T03h, \\T03l, \\T02h, \\T02l, 10',
    '\\S14h, \\S14l, \\T02h, \\T02l, 9',
    '\\T02h, \\T02l, \\S23h, \\S23l, 28',
    '\\S04h, \\S04l, \\T03h, \\T03l, 7',
    '\\S17h, \\S17l, \\T03h, \\T03l, 5',
    '\\T03h, \\T03l, \\T02l, \\T04, 3',
    '\\T03h, \\T03l, \\T02h, \\T04, 4',
]

# 生成最终代码
final_code = ""
for params_str in params_list:
    params = params_str.split(', ')
    final_code += generate_code(*params)

print(final_code)

# %%
def generate_code(outh, outl, inh, inl, n):
    code = f"""
    .macro ROLn_o {outh}, {outl}, {inh}, {inl}, {n}
    rori {outh}, {inl}, 32-{n}
    rori {outl}, {inh}, 32-({n}+1)
    .endm
    """

    return code

# 提供参数列表
params_list = [
    '\\S21h, \\S21l, \\S08h, \\S08l, 27',
    '\\S08h, \\S08l, \\S16h, \\S16l, 22',
    '\\T02h, \\T02l, \\T03h, \\T03l, 10',
    '\\T03h, \\T03l, \\T02l, \\T04, 12',
    '\\T02h, \\T02l, \\S10h, \\S10l, 1',
    '\\S02h, \\S02l, \\T03h, \\T03l, 21',
    '\\T02h, \\T02l, \\T03h, \\T04, 30',
    '\\T03h, \\T03l, \\S14h, \\S14l, 19',
    '\\S23h, \\S23l, \\T03h, \\T03l, 20',
    '\\T02h, \\T02l, \\S04h, \\S04l, 13',
    '\\T02h, \\T02l, \\S17h, \\S17l, 7',
]

# 生成最终代码
final_code = ""
for params_str in params_list:
    params = params_str.split(', ')
    final_code += generate_code(*params)

print(final_code)

# %%
def generate_code(outh, outl, inh, inl, T):
    code = f"""
    .macro ROL1XORInplace {outh}, {outl}, {inh}, {inl}, {T}
    rori {T}, {outh}, 32-1
    xor  {outh}, {outl}, {inh}
    xor  {outl}, {T}, {inl}
    .endm
    """

    return code

# 提供参数列表
params_list = [
    '\\T00h, \\T00l, \\T01h, \\T01l, \\T03h',
    '\\T00h, \\T00l, \\T01h, \\T01l, \\T03h',
    '\\T02h, \\T02l, \\T00h, \\T00l, \\T03h',
    '\\T01h, \\T01l, \\T00h, \\T00l, \\T03h',
    '\\T00h, \\T00l, \\T01h, \\T01l, \\T03h',
]

# 生成最终代码
final_code = ""
for params_str in params_list:
    params = params_str.split(', ')
    final_code += generate_code(*params)

print(final_code)

# %%
def generate_code(outh, outl, inh, inl):
    code = f"""
    .macro ROL1 {outh}, {outl}, {inh}, {inl}
    mv {outh}, {inl}
    rori {outl}, {inh}, 32-1
    .endm
    """

    return code

# 提供参数列表
params_list = [
    '\\S10h, \\S10l, \\T03h, \\T03l',
]

# 生成最终代码
final_code = ""
for params_str in params_list:
    params = params_str.split(', ')
    final_code += generate_code(*params)

print(final_code)

# %%
def generate_code(outh, outl, S00h, S00l, S01h, S01l, S02h, S02l, Th, Tl):
    code = f"""
    .macro ChiOp {outh}, {outl}, {S00h}, {S00l}, {S01h}, {S01l}, {S02h}, {S02l}, {Th}, {Tl}
    andn {Th}, {S02h}, {S01h}
    andn {Tl}, {S02l}, {S01l}
    xor {outh}, {Th}, {S00h}
    xor {outl}, {Tl}, {S00l}
    .endm
    """

    return code

# 提供参数列表
params_list = [
    '\\T03h, \\T03l, \\T00h, \\T00l, \\T01h, \\T01l, \\S08h, \\S08l, \\T03h, \\T03l',
    '\\T03h, \\T03l, \\T01h, \\T01l, \\S08h, \\S08l, \\T02h, \\T02l, \\T03h, \\T03l',
    '\\S08h, \\S08l, \\S08h, \\S08l, \\T02h, \\T02l, \\S05h, \\S05l, \\T03h, \\T03l',
    '\\T02h, \\T02l, \\T02h, \\T02l, \\S05h, \\S05l, \\T00h, \\T00l, \\T03h, \\T03l',
    '\\T03h, \\T03l, \\T01h, \\T01l, \\S14h, \\S14l, \\S10h, \\S10l, \\T03h, \\T03l',
    '\\S14h, \\S14l, \\S14h, \\S14l, \\S10h, \\S10l, \\T02h, \\T02l, \\T03h, \\T03l',
    '\\S10h, \\S10l, \\S10h, \\S10l, \\T02h, \\T02l, \\T00h, \\T00l, \\T03h, \\T03l',
    '\\T02h, \\T02l, \\T02h, \\T02l, \\T00h, \\T00l, \\T01h, \\T01l, \\T03h, \\T03l',
    '\\T03h, \\T03l, \\T00h, \\T00l, \\T01h, \\T01l, \\T02h, \\T02l, \\T03h, \\T03l',
    '\\T03h, \\T03l, \\T01h, \\T01l, \\T02h, \\T02l, \\S16h, \\S16l, \\T03h, \\T03l',
    '\\T02h, \\T02l, \\T02h, \\T02l, \\S16h, \\S16l, \\S17h, \\S17l, \\T03h, \\T03l',
    '\\S16h, \\S16l, \\S16h, \\S16l, \\S17h, \\S17l, \\T00h, \\T00l, \\T03h, \\T03l',
    '\\T03h, \\T03l, \\T00h, \\T00l, \\T01h, \\T01l, \\S21h, \\S21l, \\T03h, \\T03l',
    '\\T03h, \\T03l, \\T01h, \\T01l, \\S21h, \\S21l, \\T02h, \\T02l, \\T03h, \\T03l',
    '\\S21h, \\S21l, \\S21h, \\S21l, \\T02h, \\T02l, \\S23h, \\S23l, \\T03h, \\T03l',
    '\\T02h, \\T02l, \\T02h, \\T02l, \\S23h, \\S23l, \\T00h, \\T00l, \\T03h, \\T03l',
    '\\T03h, \\T03l, \\T00h, \\T00l, \\T01h, \\T01l, \\S02h, \\S02l, \\T03h, \\T03l',
    '\\T03h, \\T03l, \\T01h, \\T01l, \\S02h, \\S02l, \\T02h, \\T02l, \\T03h, \\T03l',
    '\\S02h, \\S02l, \\S02h, \\S02l, \\T02h, \\T02l, \\S04h, \\S04l, \\T03h, \\T03l',
    '\\T03h, \\T03l, \\T02h, \\T02l, \\S04h, \\S04l, \\T00h, \\T00l, \\T03h, \\T03l',
    '\\S04h, \\S04l, \\S04h, \\S04l, \\T00h, \\T00l, \\T01h, \\T01l, \\T03h, \\T03l',
]

# 生成最终代码
final_code = ""
for params_str in params_list:
    params = params_str.split(', ')
    final_code += generate_code(*params)

print(final_code)
